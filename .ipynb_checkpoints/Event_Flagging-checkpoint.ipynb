# %% [markdown]
# # Event Flagging

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import copy

# %%
import sys  
sys.path.insert(0, '/Volumes/Transcend/DataScience/data_bootcamp/data/cap_data')

# %%
import Metrica_IO_CF as mio
import Metrica_Viz_CF as mviz
import Metrica_Velocities_CF as mvel
import matplotlib.animation as manimation
import Metrica_PitchControl_CF as mpc

# %%
DATADIR = "/Volumes/Transcend/DataScience/data_bootcamp/data/cap_data"

# %%
game_id='/game_2'

# %%
events=pd.read_csv(DATADIR+game_id+'/events_cleaned.csv')

# %%
events=events.set_index('index')

# %%
tracking_home=pd.read_csv(DATADIR+game_id+'/tracking_home.csv')
tracking_away=pd.read_csv(DATADIR+game_id+'/tracking_away.csv')

# %%
tracking_home=tracking_home.set_index('frameIdx')
tracking_away=tracking_away.set_index('frameIdx')

# %% [markdown]
# # Ball position from tracking minus ball position from events

# %%
events.columns
# Out:
# Index(['Team', 'Type', 'From', 'To', 'Start X', 'Start Y', 'End X', 'End Y',
#        'Start Frame', 'Start Time [s]', 'Period', 'SHOTS_ON_TARGET',
#        'SHOTS_OFF_TARGET', 'DISPOSSESSED', 'POSSESSION_LOST', 'SHOT_QUALITY',
#        'POSSESSION_EVENTS', 'POSSESSION_START_CLOCK', 'POSSESSION_END_CLOCK',
#        'POSSESSION_START_FRAMEIDX', 'POSSESSION_END_FRAMEIDX',
#        'GOAL_Y_COORDINATE', 'GOAL_Z_COORDINATE', 'PASSES_SUCCESSFUL',
#        'PASSES_UNSUCCESSFUL', 'PASS_DIFFICULTY', 'Subtype', 'frameIdx',
#        'ball_x', 'ball_y', 'ball_z'],
#       dtype='object')

# %%
dist=np.sqrt((events['Start X']-events['ball_x'])**2 +(events['Start Y']-events['ball_y'])**2)

# %%
events['dist']=dist

# %%
plt.figure(figsize=(12,8))
plt.plot(events['dist'])

# %%
len(events[events['dist']>12])
# Out:
# 96

# %%
plt.plot(events['dist'][events['dist']>12])

# %%
plt.plot(events['dist'][events['dist']<12])

# %% [markdown]
# ## Shouldn't it be close to 0??

# %%
plt.plot(events['Start X'])

# %%
events[events['dist']>12].iloc[:10]
# Out:
#        Team  Type      From        To  Start X  Start Y    End X   End Y  \
# index
# 5      Away     1  443720.0   82752.0  11.6812   16.728  21.4491  29.376
# 20     Away    68       NaN       NaN -50.3500  -34.000      NaN     NaN
# 69     Home    44  421350.0       NaN -15.3064   15.640      NaN     NaN
# 86     Home    28       NaN       NaN  50.3500   34.000      NaN     NaN
# 110    Home    32       NaN       NaN  50.3500   34.000      NaN     NaN
# 113    Away    44  248981.0       NaN -15.3064   15.640      NaN     NaN
# 134    Home    68       NaN       NaN  50.3500   34.000      NaN     NaN
# 139    Home    49   92437.0       NaN  17.3204  -13.532      NaN     NaN
# 141    Away    32       NaN       NaN -50.3500  -34.000      NaN     NaN
# 145    Away     1   62535.0  110618.0  16.6155   34.000  39.4744  21.216
#
#        Start Frame  Start Time [s]  ...  GOAL_Z_COORDINATE  PASSES_SUCCESSFUL  \
# index                               ...
# 5             4920          196.80  ...                NaN                1.0
# 20           15449          617.96  ...                NaN                NaN
# 69            1269           50.76  ...                NaN                NaN
# 86           15349          613.96  ...                NaN                NaN
# 110              0            0.00  ...                NaN                NaN
# 113           1269           50.76  ...                NaN                NaN
# 134          15488          619.52  ...                NaN                NaN
# 139          16778          671.12  ...                NaN                NaN
# 141              0            0.00  ...                NaN                NaN
# 145           5620          224.80  ...                NaN                NaN
#
#        PASSES_UNSUCCESSFUL  PASS_DIFFICULTY            Subtype  frameIdx  \
# index
# 5                      NaN           0.9605               Pass      4920
# 20                     NaN              NaN  Referee_Drop_Ball     15449
# 69                     NaN              NaN             Aerial      1269
# 86                     NaN              NaN          End_delay     15349
# 110                    NaN              NaN              Start         0
# 113                    NaN              NaN             Aerial      1269
# 134                    NaN              NaN  Referee_Drop_Ball     15488
# 139                    NaN              NaN      Ball_recovery     16778
# 141                    NaN              NaN              Start         0
# 145                    NaN           0.4316               Pass      5620
#
#        ball_x  ball_y  ball_z       dist
# index
# 5       23.72   17.98    0.16  12.103727
# 20       9.30  -31.36    0.12  59.708392
# 69      -3.22   17.80    5.28  12.277893
# 86       9.64  -30.53    0.98  76.298263
# 110      0.38   -0.01    0.14  60.445686
# 113     -3.22   17.80    5.28  12.277893
# 134     13.24  -23.03    0.12  68.040966
# 139     18.58  -27.35    0.14  13.875292
# 141      0.38   -0.01    0.14  61.064335
# 145     33.45   33.92    2.09  16.834690
#
# [10 rows x 32 columns]

# %%
bad_events=events[events['dist']>12]

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.histplot(x='dist',data=bad_events)
# Out:
# <AxesSubplot:xlabel='dist', ylabel='Count'>

# %% [markdown]
# ## Build out dictionary with player id and jersey number

# %%
player_id_num=pd.read_csv(DATADIR+game_id+'/player_id_num.csv')

# %%
# initializing lists 
test_keys = list(player_id_num['playerId'])
test_values = list(player_id_num['jersey_num'])
# using zip() 
# to convert lists to dictionary 
player_dict = dict(zip(test_keys, test_values))

# %% [markdown]
# ## Change events "From" from player ID to jersey number so it matches tracking data

# %%
def isNaN(num):
    '''cute lil guy that determines if an element is nan or not'''
    return num != num

# %%
#Creating Sybtype column

jersey_num=[]
for i in range(len( events)):
    if isNaN(events['From'].iloc[i]):
        jersey_num.append(np.nan)
    else:
        jersey_num.append(player_dict[events['From'].iloc[i]])

# %%
if len(jersey_num) == events.shape[0]:
    events['From']=jersey_num
else:
    'uh oh, you\'ve got a length mismatch between your list and the events dataframe'

# %%
jersey_num=[]
for i in range(len( events)):
    if isNaN(events['To'].iloc[i]):
        jersey_num.append(np.nan)
    else:
        jersey_num.append(player_dict[events['To'].iloc[i]])

# %%
if len(jersey_num) == events.shape[0]:
    events['To']=jersey_num
else:
    'uh oh, you\'ve got a length mismatch between your list and the events dataframe'

# %%
len(jersey_num)
# Out:
# 1514

# %% [markdown]
# # Quantifying Pass probability

# %% [markdown]
# ## Defining Home/Away Passes for analysis

# %%
# away passes
away_passes=events[(events['Subtype']=='Pass') & (events['Team']=="Away")]

# %%
away_passes.shape
# Out:
# (465, 32)

# %%
# home passes
home_passes=events[(events['Subtype']=='Pass') & (events['Team']=="Home")]

# %%
home_passes.shape
# Out:
# (421, 32)

# %% [markdown]
# ## AWAY TEAM ASSESSMENT

# %%
# first get pitch control model parameters
params = mpc.default_model_params()

# %%
away_pass_success_probability=[]

# %%
for i,row in away_passes.iterrows():
    ### This if statement checks if more than 90/107 rows are nan, if so, it skips
    if list(tracking_home[tracking_home.index==row['Start Frame']].isnull().sum(axis=1))[0]>90:
        away_pass_success_probability.append( (i,np.nan) )
    else:
        pass_start_pos = np.array([row['Start X'],row['Start Y']])
        pass_target_pos = np.array([row['End X'],row['End Y']])
        pass_frame = row['Start Frame']
        # find goalkeepers for offside calculation and so player initialization works properly 
        #      - calculating them for each frame in case of substitutions
        GK_numbers = [mio.find_goalkeeper(tracking_home,int(row['Start Frame'])),
                      mio.find_goalkeeper(tracking_away,int(row['Start Frame']))]
        attacking_players = mpc.initialise_players(tracking_away.loc[pass_frame],'away',params, GK_numbers[1])
        defending_players = mpc.initialise_players(tracking_home.loc[pass_frame],'home',params, GK_numbers[0])

        Patt,Pdef = mpc.calculate_pitch_control_at_target(pass_target_pos, attacking_players, defending_players, pass_start_pos, params)

        away_pass_success_probability.append( (i,Patt) )

# %%
len(away_pass_success_probability)
# Out:
# 465

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.hist( [p[1] for p in away_pass_success_probability], np.arange(0,1.1,0.1))    
ax.set_xlabel('Pass success probability')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## New Pass Success Probability calculation with the badly labelled events removed

# %% [markdown]
# ### Industry Example

# %%
away_pass_success_probability=[]

# %%
for i,row in away_passes[away_passes['dist']<10].iterrows():
    ### This if statement checks if more than 90/107 rows are nan, if so, it skips
    if list(tracking_home[tracking_home.index==row['Start Frame']].isnull().sum(axis=1))[0]>90:
        away_pass_success_probability.append( (i,np.nan) )
    else:
        pass_start_pos = np.array([row['Start X'],row['Start Y']])
        pass_target_pos = np.array([row['End X'],row['End Y']])
        pass_frame = row['Start Frame']
        # find goalkeepers for offside calculation and so player initialization works properly 
        #      - calculating them for each frame in case of substitutions
        GK_numbers = [mio.find_goalkeeper(tracking_home,int(row['Start Frame'])),
                      mio.find_goalkeeper(tracking_away,int(row['Start Frame']))]
        attacking_players = mpc.initialise_players(tracking_away.loc[pass_frame],'away',params, GK_numbers[1])
        defending_players = mpc.initialise_players(tracking_home.loc[pass_frame],'home',params, GK_numbers[0])

        Patt,Pdef = mpc.calculate_pitch_control_at_target(pass_target_pos, attacking_players, defending_players, pass_start_pos, params)

        away_pass_success_probability.append( (i,Patt) )

# %%
len(away_pass_success_probability)
# Out:
# 447

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.hist( [p[1] for p in away_pass_success_probability], np.arange(0,1.1,0.1))    
ax.set_xlabel('Pass success probability')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # HOME TEAM ASSESSMENT

# %%
home_pass_success_probability=[]

# %%
for i,row in home_passes.iterrows():
    ### This if statement checks if more than 90/107 rows are nan, if so, it skips
    if list(tracking_home[tracking_home.index==row['Start Frame']].isnull().sum(axis=1))[0]>90:
        home_pass_success_probability.append( (i,np.nan) )
    else:
        pass_start_pos = np.array([row['Start X'],row['Start Y']])
        pass_target_pos = np.array([row['End X'],row['End Y']])
        pass_frame = row['Start Frame']
        # find goalkeepers for offside calculation and so player initialization works properly 
        #      - calculating them for each frame in case of substitutions
        GK_numbers = [mio.find_goalkeeper(tracking_home,int(row['Start Frame'])),
                      mio.find_goalkeeper(tracking_away,int(row['Start Frame']))]
        attacking_players = mpc.initialise_players(tracking_away.loc[pass_frame],'away',params, GK_numbers[1])
        defending_players = mpc.initialise_players(tracking_home.loc[pass_frame],'home',params, GK_numbers[0])

        Patt,Pdef = mpc.calculate_pitch_control_at_target(pass_target_pos, attacking_players, defending_players, pass_start_pos, params)

        home_pass_success_probability.append( (i,Patt) )

# %%
len(home_pass_success_probability)
# Out:
# 421

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.hist( [p[1] for p in home_pass_success_probability], np.arange(0,1.1,0.1))    
ax.set_xlabel('Pass success probability')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## New Pass Success Probability calculation with the badly labelled events removed

# %% [markdown]
# ### Industry Example

# %%
home_pass_success_probability=[]

# %%
for i,row in home_passes[home_passes['dist']<20].iterrows():
    ### This if statement checks if more than 90/107 rows are nan, if so, it skips
    if list(tracking_home[tracking_home.index==row['Start Frame']].isnull().sum(axis=1))[0]>90:
        home_pass_success_probability.append( (i,np.nan) )
    else:
        pass_start_pos = np.array([row['Start X'],row['Start Y']])
        pass_target_pos = np.array([row['End X'],row['End Y']])
        pass_frame = row['Start Frame']
        # find goalkeepers for offside calculation and so player initialization works properly 
        #      - calculating them for each frame in case of substitutions
        GK_numbers = [mio.find_goalkeeper(tracking_home,int(row['Start Frame'])),
                      mio.find_goalkeeper(tracking_away,int(row['Start Frame']))]
        attacking_players = mpc.initialise_players(tracking_away.loc[pass_frame],'away',params, GK_numbers[1])
        defending_players = mpc.initialise_players(tracking_home.loc[pass_frame],'home',params, GK_numbers[0])

        Patt,Pdef = mpc.calculate_pitch_control_at_target(pass_target_pos, attacking_players, defending_players, pass_start_pos, params)

        home_pass_success_probability.append( (i,Patt) )

# %%
len(home_pass_success_probability)
# Out:
# 418

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.hist( [p[1] for p in home_pass_success_probability], np.arange(0,1.1,0.1))    
ax.set_xlabel('Pass success probability')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Could try another tactic by measuring distance between "From" player to ball
# Based on the plots above I think this will get rid of a lot of issues with mismatched events

# %% [markdown]
# ## I'll have to merge events and tracking together to get this info

# %%
tracking_all=tracking_home.reset_index().merge(tracking_away.reset_index().drop(['Time [s]','Period','ball_x',
                                                                                 'ball_y','ball_z','ball_speed'],axis=1),how='left',on='frameIdx')

# %%
list(tracking_all.columns)
# Out:
# ['frameIdx',
#  'home_3_x',
#  'home_3_y',
#  'home_3_z',
#  'home_7_x',
#  'home_7_y',
#  'home_7_z',
#  'home_9_x',
#  'home_9_y',
#  'home_9_z',
#  'home_11_x',
#  'home_11_y',
#  'home_11_z',
#  'home_12_x',
#  'home_12_y',
#  'home_12_z',
#  'home_13_x',
#  'home_13_y',
#  'home_13_z',
#  'home_14_x',
#  'home_14_y',
#  'home_14_z',
#  'home_15_x',
#  'home_15_y',
#  'home_15_z',
#  'home_17_x',
#  'home_17_y',
#  'home_17_z',
#  'home_51_x',
#  'home_51_y',
#  'home_51_z',
#  'home_53_x',
#  'home_53_y',
#  'home_53_z',
#  'home_22_x',
#  'home_22_y',
#  'home_22_z',
#  'home_55_x',
#  'home_55_y',
#  'home_55_z',
#  'home_28_x',
#  'home_28_y',
#  'home_28_z',
#  'home_29_x',
#  'home_29_y',
#  'home_29_z',
#  'home_31_x',
#  'home_31_y',
#  'home_31_z',
#  'Time [s]',
#  'Period',
#  'ball_x',
#  'ball_y',
#  'ball_z',
#  'home_11_vx',
#  'home_11_vy',
#  'home_11_speed',
#  'home_12_vx',
#  'home_12_vy',
#  'home_12_speed',
#  'home_13_vx',
#  'home_13_vy',
#  'home_13_speed',
#  'home_14_vx',
#  'home_14_vy',
#  'home_14_speed',
#  'home_15_vx',
#  'home_15_vy',
#  'home_15_speed',
#  'home_17_vx',
#  'home_17_vy',
#  'home_17_speed',
#  'home_22_vx',
#  'home_22_vy',
#  'home_22_speed',
#  'home_28_vx',
#  'home_28_vy',
#  'home_28_speed',
#  'home_29_vx',
#  'home_29_vy',
#  'home_29_speed',
#  'home_3_vx',
#  'home_3_vy',
#  'home_3_speed',
#  'home_31_vx',
#  'home_31_vy',
#  'home_31_speed',
#  'home_51_vx',
#  'home_51_vy',
#  'home_51_speed',
#  'home_53_vx',
#  'home_53_vy',
#  'home_53_speed',
#  'home_55_vx',
#  'home_55_vy',
#  'home_55_speed',
#  'home_7_vx',
#  'home_7_vy',
#  'home_7_speed',
#  'home_9_vx',
#  'home_9_vy',
#  'home_9_speed',
#  'ball_speed',
#  'away_2_x',
#  'away_2_y',
#  'away_2_z',
#  'away_4_x',
#  'away_4_y',
#  'away_4_z',
#  'away_5_x',
#  'away_5_y',
#  'away_5_z',
#  'away_6_x',
#  'away_6_y',
#  'away_6_z',
#  'away_8_x',
#  'away_8_y',
#  'away_8_z',
#  'away_15_x',
#  'away_15_y',
#  'away_15_z',
#  'away_18_x',
#  'away_18_y',
#  'away_18_z',
#  'away_21_x',
#  'away_21_y',
#  'away_21_z',
#  'away_22_x',
#  'away_22_y',
#  'away_22_z',
#  'away_23_x',
#  'away_23_y',
#  'away_23_z',
#  'away_25_x',
#  'away_25_y',
#  'away_25_z',
#  'away_28_x',
#  'away_28_y',
#  'away_28_z',
#  'away_30_x',
#  'away_30_y',
#  'away_30_z',
#  'away_15_vx',
#  'away_15_vy',
#  'away_15_speed',
#  'away_18_vx',
#  'away_18_vy',
#  'away_18_speed',
#  'away_2_vx',
#  'away_2_vy',
#  'away_2_speed',
#  'away_21_vx',
#  'away_21_vy',
#  'away_21_speed',
#  'away_22_vx',
#  'away_22_vy',
#  'away_22_speed',
#  'away_23_vx',
#  'away_23_vy',
#  'away_23_speed',
#  'away_25_vx',
#  'away_25_vy',
#  'away_25_speed',
#  'away_28_vx',
#  'away_28_vy',
#  'away_28_speed',
#  'away_30_vx',
#  'away_30_vy',
#  'away_30_speed',
#  'away_4_vx',
#  'away_4_vy',
#  'away_4_speed',
#  'away_5_vx',
#  'away_5_vy',
#  'away_5_speed',
#  'away_6_vx',
#  'away_6_vy',
#  'away_6_speed',
#  'away_8_vx',
#  'away_8_vy',
#  'away_8_speed']

# %%
columns_home_velocity=[c for c in tracking_home.keys() if ((c[-3:]=='_vx') or (c[-6:]=='_speed') ) and ((c[0:4]=="home") and ((c[0:4]!="ball")))]

# %%
columns_away_velocity=[c for c in tracking_away.keys() if ((c[-3:]=='_vx' ) or (c[-6:]=='_speed')) and ((c[0:4]!="home") and (c[0:4]!="ball"))]

# %%
columns_all=columns_home_velocity+columns_away_velocity

# %%
tracking_all.drop(columns_all,axis=1)
# Out:
#         frameIdx  home_3_x  home_3_y  home_3_z  home_7_x  home_7_y  home_7_z  \
# 0              0       NaN       NaN       NaN      0.99     -9.30       0.0
# 1              1       NaN       NaN       NaN      0.99     -9.29       0.0
# 2              2       NaN       NaN       NaN      0.99     -9.27       0.0
# 3              3       NaN       NaN       NaN      1.00     -9.26       0.0
# 4              4       NaN       NaN       NaN      1.00     -9.25       0.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 151407    151407     43.96    -24.57       0.0       NaN       NaN       NaN
# 151408    151408     43.94    -24.59       0.0       NaN       NaN       NaN
# 151409    151409     43.91    -24.60       0.0       NaN       NaN       NaN
# 151410    151410     43.89    -24.62       0.0       NaN       NaN       NaN
# 151411    151411     43.87    -24.64       0.0       NaN       NaN       NaN
#
#         home_9_x  home_9_y  home_9_z  ...  away_21_vy  away_22_vy  away_23_vy  \
# 0          -0.42     23.78       0.0  ...         NaN         NaN         NaN
# 1          -0.48     23.79       0.0  ...         NaN         NaN         NaN
# 2          -0.56     23.79       0.0  ...         NaN         NaN         NaN
# 3          -0.64     23.80       0.0  ...         NaN         NaN         NaN
# 4          -0.74     23.80       0.0  ...         NaN    0.642857    0.178571
# ...          ...       ...       ...  ...         ...         ...         ...
# 151407       NaN       NaN       NaN  ...    0.214286   -0.821429    0.000000
# 151408       NaN       NaN       NaN  ...    0.214286   -0.821429    0.000000
# 151409       NaN       NaN       NaN  ...    0.267857   -0.812500    0.000000
# 151410       NaN       NaN       NaN  ...    0.321429   -0.803571    0.000000
# 151411       NaN       NaN       NaN  ...    0.375000   -0.794643    0.000000
#
#         away_25_vy  away_28_vy  away_30_vy  away_4_vy  away_5_vy  away_6_vy  \
# 0              NaN         NaN         NaN        NaN        NaN        NaN
# 1              NaN         NaN         NaN        NaN        NaN        NaN
# 2              NaN         NaN         NaN        NaN        NaN        NaN
# 3              NaN         NaN         NaN        NaN        NaN        NaN
# 4         1.321429         NaN    0.857143   1.750000   0.321429   0.071429
# ...            ...         ...         ...        ...        ...        ...
# 151407         NaN   -0.357143         NaN   0.000000   0.214286   1.107143
# 151408         NaN   -0.357143         NaN   0.035714   0.178571   1.071429
# 151409         NaN   -0.339286         NaN   0.053571   0.178571   1.071429
# 151410         NaN   -0.321429         NaN   0.071429   0.178571   1.071429
# 151411         NaN   -0.303571         NaN   0.089286   0.178571   1.071429
#
#         away_8_vy
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4        0.357143
# ...           ...
# 151407  -0.285714
# 151408  -0.250000
# 151409  -0.205357
# 151410  -0.160714
# 151411  -0.116071
#
# [151412 rows x 123 columns]

# %%
new_events=events.drop(['ball_x','ball_y','ball_z'],axis=1).merge(tracking_all.reset_index().drop(columns_all,axis=1),how='left',on='frameIdx')

# %% [markdown]
# ## Measure distance between from and ball

# %%
dist_btw=[]
for i,row in new_events.iterrows():
    if isNaN(row['From']):
        dist_btw.append(100)
    #elif isNaN():    
    else:
        tempx=row['Team'].lower() + '_' +str(int(row['From']))+ '_x'
        tempy=row['Team'].lower() + '_' +str(int(row['From']))+ '_y'
        dist_x=(row[tempx]-row['ball_x'])**2
        dist_y=(row[tempy]-row['ball_y'])**2
        #print(np.sqrt(dist_x+dist_y))
        dist_btw.append(np.sqrt(dist_x+dist_y))

# %%
len(dist_btw)
# Out:
# 1514

# %%
new_events['dist_btw']=dist_btw

# %%
len(new_events[new_events['dist_btw']>40])
# Out:
# 148

# %%
new_events[new_events['dist_btw']>40].sort_values(by='dist_btw')
# Out:
#       Team  Type  From    To  Start X  Start Y    End X   End Y  Start Frame  \
# 325   Home    49  15.0   NaN -36.1513   -0.000      NaN     NaN        18902
# 299   Home    15  15.0   NaN -36.8562    4.148      NaN     NaN        18903
# 603   Away     1   5.0  51.0  45.8185  -17.680  46.4227  -1.564        62750
# 602   Away     1   4.0   5.0   5.9413   24.344  20.9456  31.688        60887
# 960   Home     1  15.0  17.0 -18.1260  -30.396 -14.8029 -17.680       102013
# ...    ...   ...   ...   ...      ...      ...      ...     ...          ...
# 155   Away    28   NaN   NaN -50.3500  -34.000      NaN     NaN        15349
# 1137  Away    28   NaN   NaN -50.3500  -34.000      NaN     NaN       120330
# 1128  Away    28   NaN   NaN -50.3500  -34.000      NaN     NaN       112800
# 134   Home    68   NaN   NaN  50.3500   34.000      NaN     NaN        15488
# 19    Away    27   NaN   NaN -50.3500  -34.000      NaN     NaN        14733
#
#       Start Time [s]  ...  away_22_vy  away_23_vy  away_25_vy  away_28_vy  \
# 325           756.08  ...   -2.285714   -1.285714   -2.535714         NaN
# 299           756.12  ...   -2.321429   -1.357143   -2.535714         NaN
# 603          2510.00  ...   -0.071429    0.000000    1.214286         NaN
# 602          2435.48  ...    1.107143   -0.321429    1.142857         NaN
# 960          4080.52  ...   -1.678571    0.107143   -1.607143         NaN
# ...              ...  ...         ...         ...         ...         ...
# 155           613.96  ...    0.214286   -0.071429   -0.357143         NaN
# 1137         4813.20  ...    0.928571   -0.107143         NaN         NaN
# 1128         4512.00  ...    1.285714    0.000000         NaN         NaN
# 134           619.52  ...    0.178571    0.428571   -0.357143         NaN
# 19            589.32  ...   -0.500000    0.000000   -0.071429         NaN
#
#       away_30_vy  away_4_vy  away_5_vy  away_6_vy  away_8_vy    dist_btw
# 325    -0.678571   4.535714  -5.035714   0.571429  -1.142857   40.009475
# 299    -0.678571   4.464286  -5.071429   0.607143  -1.142857   40.015882
# 603     0.000000  -2.857143   0.607143   0.071429   3.750000   40.084552
# 602     0.607143  -0.071429   1.071429   1.000000   1.214286   40.172130
# 960    -0.785714   0.535714  -0.500000   2.500000  -1.928571   40.217202
# ...          ...        ...        ...        ...        ...         ...
# 155    -0.392857  -0.964286   0.035714  -1.107143  -0.642857  100.000000
# 1137   -1.035714   1.142857   0.142857  -0.714286   0.000000  100.000000
# 1128    0.000000   0.964286   0.785714   0.714286   1.000000  100.000000
# 134     0.392857   0.642857  -0.107143  -0.142857  -4.892857  100.000000
# 19      1.142857   2.500000   0.250000  -0.535714  -0.250000  100.000000
#
# [148 rows x 153 columns]

# %% [markdown]
# #####

# %% [markdown]
# ## AWAY TEAM ASSESSMENT

# %%
# first get pitch control model parameters
params = mpc.default_model_params()

# %%
away_pass_success_probability=[]

# %%
for i,row in away_passes.iterrows():
    ### This if statement checks if more than 90/107 rows are nan, if so, it skips
    if list(tracking_home[tracking_home.index==row['Start Frame']].isnull().sum(axis=1))[0]>90:
        away_pass_success_probability.append( (i,np.nan) )
    else:
        pass_start_pos = np.array([row['Start X'],row['Start Y']])
        pass_target_pos = np.array([row['End X'],row['End Y']])
        pass_frame = row['Start Frame']
        # find goalkeepers for offside calculation and so player initialization works properly 
        #      - calculating them for each frame in case of substitutions
        GK_numbers = [mio.find_goalkeeper(tracking_home,int(row['Start Frame'])),
                      mio.find_goalkeeper(tracking_away,int(row['Start Frame']))]
        attacking_players = mpc.initialise_players(tracking_away.loc[pass_frame],'away',params, GK_numbers[1])
        defending_players = mpc.initialise_players(tracking_home.loc[pass_frame],'home',params, GK_numbers[0])

        Patt,Pdef = mpc.calculate_pitch_control_at_target(pass_target_pos, attacking_players, defending_players, pass_start_pos, params)

        away_pass_success_probability.append( (i,Patt) )

# %%
len(away_pass_success_probability)
# Out:
# 465

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.hist( [p[1] for p in away_pass_success_probability], np.arange(0,1.1,0.1))    
ax.set_xlabel('Pass success probability')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## New Pass Success Probability calculation with the badly labelled events removed

# %% [markdown]
# ### Industry Example

# %%
away_pass_success_probability=[]

# %%
for i,row in away_passes[away_passes['dist']<7].iterrows():
    ### This if statement checks if more than 90/107 rows are nan, if so, it skips
    if list(tracking_home[tracking_home.index==row['Start Frame']].isnull().sum(axis=1))[0]>90:
        away_pass_success_probability.append( (i,np.nan) )
    else:
        pass_start_pos = np.array([row['Start X'],row['Start Y']])
        pass_target_pos = np.array([row['End X'],row['End Y']])
        pass_frame = row['Start Frame']
        # find goalkeepers for offside calculation and so player initialization works properly 
        #      - calculating them for each frame in case of substitutions
        GK_numbers = [mio.find_goalkeeper(tracking_home,int(row['Start Frame'])),
                      mio.find_goalkeeper(tracking_away,int(row['Start Frame']))]
        attacking_players = mpc.initialise_players(tracking_away.loc[pass_frame],'away',params, GK_numbers[1])
        defending_players = mpc.initialise_players(tracking_home.loc[pass_frame],'home',params, GK_numbers[0])

        Patt,Pdef = mpc.calculate_pitch_control_at_target(pass_target_pos, attacking_players, defending_players, pass_start_pos, params)

        away_pass_success_probability.append( (i,Patt) )

# %%
len(away_pass_success_probability)
# Out:
# 419

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.hist( [p[1] for p in away_pass_success_probability], np.arange(0,1.1,0.1))    
ax.set_xlabel('Pass success probability')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Try out ways of flagging bad events

# %%
test_events=copy.deepcopy(new_events)

# %%
test_events=test_events[list(new_events.drop(['dist'],axis=1).columns)+['dist']]

# %% [markdown]
# ### First one is to filter the events when the distance between ball and start location (in event) is greater than 7 AND the distance between the ball carrier and the ball is greater than 15 m

# %%
test_events[(test_events['dist']>7)&(test_events['dist_btw']>15)]
# Out:
#       Team  Type  From   To  Start X  Start Y    End X   End Y  Start Frame  \
# 5     Away     1  30.0  5.0  11.6812   16.728  21.4491  29.376         4920
# 9     Away    15   4.0  NaN  23.9666   12.648      NaN     NaN         7158
# 20    Away    68   NaN  NaN -50.3500  -34.000      NaN     NaN        15449
# 22    Away     1  30.0  8.0 -19.4351    1.088 -47.5304  12.648        17721
# 45    Away     1  25.0  NaN -23.0603  -34.000   9.9693 -30.328         2579
# ...    ...   ...   ...  ...      ...      ...      ...     ...          ...
# 1454  Home     4   3.0  NaN  -2.2154   -9.452      NaN     NaN       145858
# 1460  Home     1  28.0  3.0  18.8309  -11.288 -12.8896  -3.536       134801
# 1472  Home     2   3.0  NaN -21.2477   -4.284 -36.9569 -30.872       142007
# 1503  Away     5   6.0  NaN -46.7248  -35.224      NaN     NaN       141267
# 1513  Home    13   3.0  NaN -29.4044  -12.988      NaN     NaN       149000
#
#       Start Time [s]  ...  away_23_vy  away_25_vy  away_28_vy  away_30_vy  \
# 5             196.80  ...    0.071429    0.571429         NaN    0.250000
# 9             286.32  ...    0.071429    1.964286         NaN   -0.178571
# 20            617.96  ...    0.178571   -0.464286         NaN    0.000000
# 22            708.84  ...    0.500000    0.857143         NaN    1.928571
# 45            103.16  ...    0.678571   -0.714286         NaN   -0.035714
# ...              ...  ...         ...         ...         ...         ...
# 1454         5834.32  ...    0.642857         NaN    3.178571         NaN
# 1460         5392.04  ...    0.571429         NaN         NaN         NaN
# 1472         5680.28  ...   -0.357143         NaN   -1.500000         NaN
# 1503         5650.68  ...    0.071429         NaN    0.642857         NaN
# 1513         5960.00  ...    0.821429         NaN   -1.071429         NaN
#
#       away_4_vy  away_5_vy  away_6_vy  away_8_vy    dist_btw       dist
# 5     -0.678571  -0.035714  -0.607143   0.785714   16.840561  12.103727
# 9      1.928571   1.392857   3.285714   0.642857   35.894601   9.004967
# 20     0.285714  -0.892857  -1.607143  -2.928571  100.000000  59.708392
# 22     0.642857   2.357143   1.464286   3.035714   32.795904   7.466214
# 45    -2.285714   0.000000  -1.142857  -0.464286   22.872046   8.685287
# ...         ...        ...        ...        ...         ...        ...
# 1454   1.321429   2.964286   2.285714   0.857143   42.289414  18.816772
# 1460   2.928571   0.142857  -0.750000  -1.071429   20.015756   7.872494
# 1472  -2.571429  -1.464286  -2.464286  -2.035714   18.470912   8.396705
# 1503  -2.535714  -0.500000   0.214286  -0.428571   28.837538   7.558891
# 1513   1.678571   1.607143   1.107143   1.964286   17.516635   7.217838
#
# [129 rows x 153 columns]

# %% [markdown]
# ### Second one is to label "Good" events where the players aren't labelled properly
# filter the events when the distance between ball and start location (in event) is LESS than 7 AND the distance between the ball carrier and the ball is GREATER than 20 m

# %%
test_events[(test_events['dist']<7)&(test_events['dist_btw']>20)]
# Out:
#       Team  Type  From    To  Start X  Start Y    End X   End Y  Start Frame  \
# 1     Away    49   4.0   NaN -23.6645   30.192      NaN     NaN         1410
# 2     Away     1   4.0  22.0 -24.4701   30.192  -1.3091  30.600         1418
# 3     Away    49  18.0   NaN -23.0603  -27.744      NaN     NaN         2134
# 4     Away     1   5.0  30.0  40.9849   30.804  13.3931  16.320         4832
# 6     Home    12   9.0   NaN  45.5164   19.108  29.8072  32.436         5699
# ...    ...   ...   ...   ...      ...      ...      ...     ...          ...
# 1497  Home     1   3.0  22.0  -7.9553   16.388 -29.0016  19.584       137740
# 1501  Home     1   3.0   4.0  -8.6602   13.736 -15.7092  28.560       140362
# 1506  Away     1   5.0   2.0  20.4421  -31.280  11.7819 -25.024       143574
# 1509  Home     1  31.0   2.0 -37.7625   23.324 -38.8702  -0.748       146760
# 1512  Home     1  29.0  28.0  12.3861  -10.064  18.7302 -21.352       148139
#
#       Start Time [s]  ...  away_23_vy  away_25_vy  away_28_vy  away_30_vy  \
# 1              56.40  ...    0.178571   -0.607143         NaN    2.714286
# 2              56.72  ...   -0.107143    0.035714         NaN    2.714286
# 3              85.36  ...   -0.285714   -1.392857         NaN   -2.071429
# 4             193.28  ...    0.035714    2.107143         NaN   -0.500000
# 6             227.96  ...   -0.785714   -1.928571         NaN   -0.214286
# ...              ...  ...         ...         ...         ...         ...
# 1497         5509.60  ...   -0.178571         NaN         NaN         NaN
# 1501         5614.48  ...   -0.428571         NaN   -1.357143         NaN
# 1506         5742.96  ...    0.250000         NaN   -1.142857         NaN
# 1509         5870.40  ...    0.464286         NaN    4.785714         NaN
# 1512         5925.56  ...    0.321429         NaN    1.250000         NaN
#
#       away_4_vy  away_5_vy  away_6_vy  away_8_vy   dist_btw      dist
# 1     -0.571429   1.535714   0.464286   3.500000  20.793251  3.584457
# 2     -0.964286   1.321429   0.035714   3.642857  22.933875  5.727390
# 3     -2.892857  -0.250000  -3.035714  -1.000000  39.397504  3.124190
# 4     -0.857143  -0.321429   1.571429  -2.321429  34.505063  5.166365
# 6     -0.571429  -1.035714  -0.964286  -1.285714  29.811939  3.197371
# ...         ...        ...        ...        ...        ...       ...
# 1497  -0.750000   1.000000  -1.285714  -0.142857  42.377629  1.947922
# 1501  -1.428571  -0.392857   0.285714   0.500000  27.519684  4.248219
# 1506  -0.785714  -0.178571   0.321429   0.321429  31.781078  2.028090
# 1509   3.035714   1.642857   1.392857   1.500000  24.533683  2.370606
# 1512   1.571429   0.250000  -0.678571  -1.250000  20.801385  4.667121
#
# [476 rows x 153 columns]

# %%
print('There are {} Events in the "Good" event, but wrongly labelled with player category'.format(len(test_events[(test_events['dist']<7)&(test_events['dist_btw']>20)])))
# Out:
# There are 476 Events in the "Good" event, but wrongly labelled with player category

# %%
print('There are {} Events in the "Bad" event category'.format(len(test_events[(test_events['dist']>7)&(test_events['dist_btw']>15)])))
# Out:
# There are 129 Events in the "Bad" event category

# %%
list(test_events.columns)
# Out:
# ['Team',
#  'Type',
#  'From',
#  'To',
#  'Start X',
#  'Start Y',
#  'End X',
#  'End Y',
#  'Start Frame',
#  'Start Time [s]',
#  'Period_x',
#  'SHOTS_ON_TARGET',
#  'SHOTS_OFF_TARGET',
#  'DISPOSSESSED',
#  'POSSESSION_LOST',
#  'SHOT_QUALITY',
#  'POSSESSION_EVENTS',
#  'POSSESSION_START_CLOCK',
#  'POSSESSION_END_CLOCK',
#  'POSSESSION_START_FRAMEIDX',
#  'POSSESSION_END_FRAMEIDX',
#  'GOAL_Y_COORDINATE',
#  'GOAL_Z_COORDINATE',
#  'PASSES_SUCCESSFUL',
#  'PASSES_UNSUCCESSFUL',
#  'PASS_DIFFICULTY',
#  'Subtype',
#  'frameIdx',
#  'index',
#  'home_3_x',
#  'home_3_y',
#  'home_3_z',
#  'home_7_x',
#  'home_7_y',
#  'home_7_z',
#  'home_9_x',
#  'home_9_y',
#  'home_9_z',
#  'home_11_x',
#  'home_11_y',
#  'home_11_z',
#  'home_12_x',
#  'home_12_y',
#  'home_12_z',
#  'home_13_x',
#  'home_13_y',
#  'home_13_z',
#  'home_14_x',
#  'home_14_y',
#  'home_14_z',
#  'home_15_x',
#  'home_15_y',
#  'home_15_z',
#  'home_17_x',
#  'home_17_y',
#  'home_17_z',
#  'home_51_x',
#  'home_51_y',
#  'home_51_z',
#  'home_53_x',
#  'home_53_y',
#  'home_53_z',
#  'home_22_x',
#  'home_22_y',
#  'home_22_z',
#  'home_55_x',
#  'home_55_y',
#  'home_55_z',
#  'home_28_x',
#  'home_28_y',
#  'home_28_z',
#  'home_29_x',
#  'home_29_y',
#  'home_29_z',
#  'home_31_x',
#  'home_31_y',
#  'home_31_z',
#  'Time [s]',
#  'Period_y',
#  'ball_x',
#  'ball_y',
#  'ball_z',
#  'home_11_vy',
#  'home_12_vy',
#  'home_13_vy',
#  'home_14_vy',
#  'home_15_vy',
#  'home_17_vy',
#  'home_22_vy',
#  'home_28_vy',
#  'home_29_vy',
#  'home_3_vy',
#  'home_31_vy',
#  'home_51_vy',
#  'home_53_vy',
#  'home_55_vy',
#  'home_7_vy',
#  'home_9_vy',
#  'ball_speed',
#  'away_2_x',
#  'away_2_y',
#  'away_2_z',
#  'away_4_x',
#  'away_4_y',
#  'away_4_z',
#  'away_5_x',
#  'away_5_y',
#  'away_5_z',
#  'away_6_x',
#  'away_6_y',
#  'away_6_z',
#  'away_8_x',
#  'away_8_y',
#  'away_8_z',
#  'away_15_x',
#  'away_15_y',
#  'away_15_z',
#  'away_18_x',
#  'away_18_y',
#  'away_18_z',
#  'away_21_x',
#  'away_21_y',
#  'away_21_z',
#  'away_22_x',
#  'away_22_y',
#  'away_22_z',
#  'away_23_x',
#  'away_23_y',
#  'away_23_z',
#  'away_25_x',
#  'away_25_y',
#  'away_25_z',
#  'away_28_x',
#  'away_28_y',
#  'away_28_z',
#  'away_30_x',
#  'away_30_y',
#  'away_30_z',
#  'away_15_vy',
#  'away_18_vy',
#  'away_2_vy',
#  'away_21_vy',
#  'away_22_vy',
#  'away_23_vy',
#  'away_25_vy',
#  'away_28_vy',
#  'away_30_vy',
#  'away_4_vy',
#  'away_5_vy',
#  'away_6_vy',
#  'away_8_vy',
#  'dist_btw',
#  'dist']

# %%
test_events.columns
# Out:
# Index(['Team', 'Type', 'From', 'To', 'Start X', 'Start Y', 'End X', 'End Y',
#        'Start Frame', 'Start Time [s]',
#        ...
#        'away_23_vy', 'away_25_vy', 'away_28_vy', 'away_30_vy', 'away_4_vy',
#        'away_5_vy', 'away_6_vy', 'away_8_vy', 'dist_btw', 'dist'],
#       dtype='object', length=153)

# %% [markdown]
# ### Build column with vector direction and magnitude from start/end in events file so I can add it to the start of ball position and shift things

# %%
new_vec_x=[]
new_vec_y=[]
for i in range(len(events)):
    new_vec_x.append((events['End X'].iloc[i]-events['Start X'].iloc[i]) + events['ball_x'].iloc[i])
    new_vec_y.append((events['End Y'].iloc[i]-events['Start Y'].iloc[i]) + events['ball_y'].iloc[i])

# %%
test_events['new_event_end_x']=new_vec_x
test_events['new_event_end_y']=new_vec_y

# %%
test_events
# Out:
#       Team  Type  From    To  Start X  Start Y    End X   End Y  Start Frame  \
# 0     Home     1  51.0  53.0  28.9009   12.104 -16.4141  12.920         1209
# 1     Away    49   4.0   NaN -23.6645   30.192      NaN     NaN         1410
# 2     Away     1   4.0  22.0 -24.4701   30.192  -1.3091  30.600         1418
# 3     Away    49  18.0   NaN -23.0603  -27.744      NaN     NaN         2134
# 4     Away     1   5.0  30.0  40.9849   30.804  13.3931  16.320         4832
# ...    ...   ...   ...   ...      ...      ...      ...     ...          ...
# 1509  Home     1  31.0   2.0 -37.7625   23.324 -38.8702  -0.748       146760
# 1510  Away    74  25.0   NaN -45.0129  -12.580      NaN     NaN       147002
# 1511  Home     1   7.0  29.0   5.9413  -14.552  12.3861 -10.064       148117
# 1512  Home     1  29.0  28.0  12.3861  -10.064  18.7302 -21.352       148139
# 1513  Home    13   3.0   NaN -29.4044  -12.988      NaN     NaN       149000
#
#       Start Time [s]  ...  away_28_vy  away_30_vy  away_4_vy  away_5_vy  \
# 0              48.36  ...         NaN    0.928571   0.428571   1.607143
# 1              56.40  ...         NaN    2.714286  -0.571429   1.535714
# 2              56.72  ...         NaN    2.714286  -0.964286   1.321429
# 3              85.36  ...         NaN   -2.071429  -2.892857  -0.250000
# 4             193.28  ...         NaN   -0.500000  -0.857143  -0.321429
# ...              ...  ...         ...         ...        ...        ...
# 1509         5870.40  ...    4.785714         NaN   3.035714   1.642857
# 1510         5880.08  ...   -0.821429         NaN   0.678571  -0.785714
# 1511         5924.68  ...    0.464286         NaN   0.107143  -0.892857
# 1512         5925.56  ...    1.250000         NaN   1.571429   0.250000
# 1513         5960.00  ...   -1.071429         NaN   1.678571   1.607143
#
#       away_6_vy  away_8_vy   dist_btw      dist  new_event_end_x  \
# 0      1.357143   2.392857   0.953415  6.923609          -9.6050
# 1      0.464286   3.500000  20.793251  3.584457              NaN
# 2      0.035714   3.642857  22.933875  5.727390           4.0510
# 3     -3.035714  -1.000000  39.397504  3.124190              NaN
# 4      1.571429  -2.321429  34.505063  5.166365          18.5082
# ...         ...        ...        ...       ...              ...
# 1509   1.392857   1.500000  24.533683  2.370606         -41.1177
# 1510  -0.535714   4.607143        NaN  5.214623              NaN
# 1511  -0.464286  -2.107143        NaN  3.181797          11.7048
# 1512  -0.678571  -1.250000  20.801385  4.667121          15.6841
# 1513   1.107143   1.964286  17.516635  7.217838              NaN
#
#       new_event_end_y
# 0              11.666
# 1                 NaN
# 2              32.618
# 3                 NaN
# 4              17.046
# ...               ...
# 1509           -1.502
# 1510              NaN
# 1511          -13.172
# 1512          -24.888
# 1513              NaN
#
# [1514 rows x 155 columns]

# %% [markdown]
# ## Test out this now method to plot events using the ball position and the original vector magnitude and direction

# %%
def plot_events_new( events, figax=None, field_dimen = (107,68.6), indicators = ['Marker','Arrow'], color='r', marker_style = 'o', alpha = 0.5, annotate=False):
    """ plot_events( events )
    
    Plots Metrica event positions on a football pitch. event data can be a single or several rows of a data frame. All distances should be in meters.
    
    Parameters
    -----------
        events: row (i.e. instant) of the home team tracking data frame
        fig,ax: Can be used to pass in the (fig,ax) objects of a previously generated pitch. Set to (fig,ax) to use an existing figure, or None (the default) to generate a new pitch plot, 
        field_dimen: tuple containing the length and width of the pitch in meters. Default is (106,68)
        indicators: List containing choices on how to plot the event. 'Marker' places a marker at the 'Start X/Y' location of the event; 'Arrow' draws an arrow from the start to end locations. Can choose one or both.
        color: color of indicator. Default is 'r' (red)
        marker_style: Marker type used to indicate the event position. Default is 'o' (filled ircle).
        alpha: alpha of event marker. Default is 0.5    
        annotate: Boolean determining whether text annotation from event data 'Subtype' and 'From' fields is shown on plot. Default is False.
        
    Returrns
    -----------
       fig,ax : figure and aixs objects (so that other data can be plotted onto the pitch)

    """

    if figax is None: # create new pitch 
        fig,ax = plot_pitch( field_dimen = field_dimen )
    else: # overlay on a previously generated pitch
        fig,ax = figax 
    for i,row in events.iterrows():
        if 'Marker' in indicators:
            ax.plot(  row['ball_x'], row['ball_y'], color+marker_style, alpha=alpha )
        if 'Arrow' in indicators:
            ax.annotate("", xy=row[['new_event_end_x','new_event_end_y']], xytext=row[['ball_x','ball_y']], alpha=alpha, arrowprops=dict(alpha=alpha,width=0.5,headlength=4.0,headwidth=4.0,color=color),annotation_clip=False)
        if annotate:
            #textstring = str(row['Subtype']) + ': ' + str(row['From']) #- if I have a subtype column
            textstring = str(row['From']) 
            ax.text( row['ball_x'], row['ball_y'], textstring, fontsize=10, color=color)
    return fig,ax

# %% [markdown]
# ## Doesn't look like 7 is large enough to filter out bad events that were mislabeled
# Looks like 20 is the number that is right filter here
#
# (17 worked when I was also filtering for distance of ball position to player tagged)
#
#
# This code will work - run it to see what I mean:
#
# `for i,row in test_events[(test_events['dist']>17)&(test_events['dist_btw']>15)].iterrows():
#     if isNaN(row['End X']):
#         print('----')
#     else:
#         event_frame=row['Start Frame']
#         fig,ax=mviz.plot_frame(tracking_home.loc[event_frame], tracking_away.loc[event_frame],include_player_velocities=True, annotate=True)# plot the 3 events leading up to the second goal
#         plot_events_new(pd.DataFrame(row).T.loc[i:i], color='y', alpha=1.0,indicators = ['Marker','Arrow'], annotate=True,figax = (fig,ax))
#         ## need this line for dataset with no "receiver ID/To"
#         ax.set_title("Team {}, From: {} To: {} ".format(row['Team'],row['From'],row['To']))
#         ##
#        ax.set_xlabel("Ball loc_tracking: {},{}, Ball loc_events: {},{}".format(tracking_home['ball_x'].loc[event_frame],
#                                                                                 tracking_home['ball_y'].loc[event_frame],
#                                                                                 round(row['Start X'],2), round(row['Start Y'],2)),fontsize=12)`
#
# `

# %% [markdown]
# # Sorted Events into 3 Categories:
# 1. **`bad_events`** - events that are just wrongly labelled
# 2. **`good_event_wrongly_labelled`** - events that are labelled with the players incorrectly but are correct
# 3. **`good_events`** - events that are labelled correctly and are accurate

# %%
bad_events=test_events[test_events.index.isin(list(test_events[(test_events['dist']>20)].index))]

# %%
bad_events.shape
# Out:
# (29, 155)

# %%
print("By Applying this filter you get rid of {}, wrongly labelled events".format(len(test_events[(test_events['dist']>20)])))
# Out:
# By Applying this filter you get rid of 29, wrongly labelled events

# %%
events=test_events[~test_events.index.isin(list(test_events[(test_events['dist']>20)].index))]

# %%
events.shape
# Out:
# (1485, 155)

# %%
good_events=test_events[test_events.index.isin(list(test_events[(test_events['dist']<20)&(test_events['dist_btw']<15)].index))]

# %%
print("The filter finds that {}, are correctly labelled and accurate".format(len(good_events)))
# Out:
# The filter finds that 322, are correctly labelled and accurate

# %%
good_event_wrongly_labelled=events[~events.index.isin(list(events[(events['dist']<20)&(events['dist_btw']<15)].index))]

# %%
print("The filter finds that {}, are incorrectly labelled but accurate".format(len(good_event_wrongly_labelled)))
# Out:
# The filter finds that 1163, are incorrectly labelled but accurate

# %% [markdown]
# ### Export bad, good, and wrongly labelled events

# %%
bad_events.to_csv(DATADIR+game_id+'/bad_events_merged.csv')

# %%
good_events.to_csv(DATADIR+game_id+'/good_events.csv')

# %%
good_event_wrongly_labelled.to_csv(DATADIR+game_id+'/good_events_wrong_label.csv')
