# %% [markdown]
# # Pitch Control

# %%
DATADIR = "/Volumes/Transcend/DataScience/data_bootcamp/data/cap_data"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import copy

# %%
import sys  
sys.path.insert(0, '/Volumes/Transcend/DataScience/data_bootcamp/data/cap_data')

# %%
import Metrica_IO_CF as mio
import Metrica_Viz_CF_ADJ as mviz
import Metrica_Velocities_CF as mvel
import matplotlib.animation as manimation
import Metrica_PitchControl_CF_ADJ as mpc

# %%
events=pd.read_csv(DATADIR+'/events_cleaned_merged.csv')

# %%
tracking_home=pd.read_csv(DATADIR+'/tracking_home.csv')
tracking_away=pd.read_csv(DATADIR+'/tracking_away.csv')

# %%
events=events.set_index('index')

# %% [markdown]
# ## For the away team it is not plotting player 124567, and there are only 10 players on the pitch - but no red cards were given. Injury?

# %% [markdown]
# ## Understanding how pitch control works

# %%
field_dimen=(100.6,68.9)
n_grid_cells_x=50
n_grid_cells_y = int(n_grid_cells_x*field_dimen[1]/field_dimen[0])
dx = field_dimen[0]/n_grid_cells_x
dy = field_dimen[1]/n_grid_cells_y
xgrid = np.arange(n_grid_cells_x)*dx - field_dimen[0]/2. + dx/2.
ygrid = np.arange(n_grid_cells_y)*dy - field_dimen[1]/2. + dy/2.

# %%
xgrid
# Out:
# array([-49.294, -47.282, -45.27 , -43.258, -41.246, -39.234, -37.222,
#        -35.21 , -33.198, -31.186, -29.174, -27.162, -25.15 , -23.138,
#        -21.126, -19.114, -17.102, -15.09 , -13.078, -11.066,  -9.054,
#         -7.042,  -5.03 ,  -3.018,  -1.006,   1.006,   3.018,   5.03 ,
#          7.042,   9.054,  11.066,  13.078,  15.09 ,  17.102,  19.114,
#         21.126,  23.138,  25.15 ,  27.162,  29.174,  31.186,  33.198,
#         35.21 ,  37.222,  39.234,  41.246,  43.258,  45.27 ,  47.282,
#         49.294])

# %%
ygrid
# Out:
# array([-33.43676471, -31.41029412, -29.38382353, -27.35735294,
#        -25.33088235, -23.30441176, -21.27794118, -19.25147059,
#        -17.225     , -15.19852941, -13.17205882, -11.14558824,
#         -9.11911765,  -7.09264706,  -5.06617647,  -3.03970588,
#         -1.01323529,   1.01323529,   3.03970588,   5.06617647,
#          7.09264706,   9.11911765,  11.14558824,  13.17205882,
#         15.19852941,  17.225     ,  19.25147059,  21.27794118,
#         23.30441176,  25.33088235,  27.35735294,  29.38382353,
#         31.41029412,  33.43676471])

# %%
len(ygrid)
# Out:
# 34

# %%
len(xgrid)
# Out:
# 50

# %%
#plt.figure(figsize=(10,8))
mviz.plot_pitch()
for i,xline in enumerate(xgrid):
    plt.axvline(x=xline)
    if i <34:
        plt.axhline(y=ygrid[i],color='r')

# %% [markdown]
# Most important params appear to be ball start position - it then calculates pitch control @ each grid as shown above based on the ball position
#
# **Ball start position is defined using EVENT DATA:**
# - change pitch control model to pull ball start position from tracking data instead
#
# **Improvements to make:**
# - incorporate ball speed from target data into this model. Right now it is using a default of "average ball speed" that is a scalar and set as 15.0 m/s
# - incorporate player specific max speeds. Currently within the `simple_time_to_intercept` function,  the `player` class and assumes certain player attributes like `vmax`,within `params` as `max_player_speed`==12m/s

# %% [markdown]
# ## Start some computations

# %%
# first get pitch control model parameters
params = mpc.default_model_params()

# %%
print(params)
# Out:
# {'max_player_accel': 7.0, 'max_player_speed': 5.0, 'reaction_time': 0.7, 'tti_sigma': 0.45, 'kappa_def': 1.0, 'lambda_att': 4.3, 'lambda_def': 4.3, 'lambda_gk': 12.899999999999999, 'average_ball_speed': 15.0, 'int_dt': 0.04, 'max_int_time': 10, 'model_converge_tol': 0.01, 'time_to_control_att': 3.3202550055547313, 'time_to_control_def': 3.3202550055547313}

# %%
events.iloc[100]['Start Frame']
# Out:
# 6983.0

# %%
# find goalkeepers for offside calculation
GK_numbers = [mio.find_goalkeeper(tracking_home,int(events.iloc[100]['Start Frame'])),mio.find_goalkeeper(tracking_away,int(events.iloc[100]['Start Frame']))]

# %%
"home keeper number: {} away keeper number: {}".format(GK_numbers[0],GK_numbers[1])
# Out:
# 'home keeper number: 41556 away keeper number: 107672'

# %%
type(GK_numbers[0])
# Out:
# str

# %%
tracking_home=tracking_home.set_index('frameIdx')

# %%
tracking_away=tracking_away.set_index('frameIdx')

# %% [markdown]
# ## Defining Home/Away Passes for analysis

# %%
# away passes
away_passes=events[(events['Subtype']=='Pass') & (events['Team']=="Away")]

# %%
away_passes.shape
# Out:
# (640, 17)

# %%
# home passes
home_passes=events[(events['Subtype']=='Pass') & (events['Team']=="Home")]

# %%
home_passes.shape
# Out:
# (414, 17)

# %%
home_passes
# Out:
#        Team  Type      From        To  Start X  Start Y    End X   End Y  \
# index
# 13     Home     1  424622.0  107672.0 -18.5288   26.112 -44.0059  15.504
# 18     Home     1  425341.0  151955.0  17.8239   -9.248  15.2057 -10.608
# 20     Home     1  151955.0  110619.0  16.0113   -6.732  18.5288  -1.632
# 22     Home     1  110619.0  249203.0  18.5288   -1.632  19.4351  22.304
# 23     Home     1  249203.0  110619.0  19.6365   24.684  22.2547  21.488
# ...     ...   ...       ...       ...      ...      ...      ...     ...
# 1707   Home     1  219527.0  151940.0  -5.5385  -15.504  -4.5315   6.188
# 1708   Home     1  151940.0   82526.0 -12.7889    7.344 -28.8002 -28.968
# 1709   Home     1   82526.0  219527.0 -27.1890  -27.540 -22.0533 -19.992
# 1710   Home     1  219527.0  224546.0 -22.0533  -19.992 -22.2547  -8.976
# 1711   Home     1  224546.0       NaN -23.1610   -5.712 -10.5735   6.800
#
#        Start Frame  Start Time [s]  Period SIDE_OF_PITCH Subtype  frameIdx  \
# index
# 13           717.0           28.68       1         Right    Pass       717
# 18          1528.0           61.12       1          Left    Pass      1528
# 20          1568.0           62.72       1          Left    Pass      1568
# 22          1627.0           65.08       1          Left    Pass      1627
# 23          1711.0           68.44       1         Right    Pass      1711
# ...            ...             ...     ...           ...     ...       ...
# 1707      138522.0         5540.88       2          Left    Pass    138522
# 1708      138659.0         5546.36       2         Right    Pass    138659
# 1709      138770.0         5550.80       2          Left    Pass    138770
# 1710      138826.0         5553.04       2          Left    Pass    138826
# 1711      138887.0         5555.48       2          Left    Pass    138887
#
#        ball_x  ball_y  ball_z
# index
# 13     -25.18   19.93    0.14
# 18      14.01  -14.12    1.39
# 20      12.21  -11.58    0.88
# 22      17.25    0.55    0.06
# 23      13.07   22.78    0.08
# ...       ...     ...     ...
# 1707    -4.58  -10.24    0.10
# 1708   -11.85   11.16    0.73
# 1709   -25.38  -22.83    0.09
# 1710   -16.85  -12.07    0.06
# 1711   -12.41    5.16    0.06
#
# [414 rows x 17 columns]

# %%
home_passes.iloc[:5]
# Out:
#        Team  Type      From        To  Start X  Start Y    End X   End Y  \
# index
# 13     Home     1  424622.0  107672.0 -18.5288   26.112 -44.0059  15.504
# 18     Home     1  425341.0  151955.0  17.8239   -9.248  15.2057 -10.608
# 20     Home     1  151955.0  110619.0  16.0113   -6.732  18.5288  -1.632
# 22     Home     1  110619.0  249203.0  18.5288   -1.632  19.4351  22.304
# 23     Home     1  249203.0  110619.0  19.6365   24.684  22.2547  21.488
#
#        Start Frame  Start Time [s]  Period SIDE_OF_PITCH Subtype  frameIdx  \
# index
# 13           717.0           28.68       1         Right    Pass       717
# 18          1528.0           61.12       1          Left    Pass      1528
# 20          1568.0           62.72       1          Left    Pass      1568
# 22          1627.0           65.08       1          Left    Pass      1627
# 23          1711.0           68.44       1         Right    Pass      1711
#
#        ball_x  ball_y  ball_z
# index
# 13     -25.18   19.93    0.14
# 18      14.01  -14.12    1.39
# 20      12.21  -11.58    0.88
# 22      17.25    0.55    0.06
# 23      13.07   22.78    0.08

# %%
# plot a random frame, plotting the player velocities using quivers
mviz.plot_frame(tracking_home.loc[10000], tracking_away.loc[10000], include_player_velocities=True, annotate=True,field_dimen=(100.6,68.9))
# Out:
# (<Figure size 864x576 with 1 Axes>, <AxesSubplot:>)

# %%
""" **** calculate pass probability for every home team succesful pass **** """
# get all home passes
# home_passes = events[ (events['Type'].isin(['PASS'])) & (events['Team']=='Home') ]

# list for storing pass probablities
pass_success_probability = []

# %%
home_passes.iloc[:5]
# Out:
#        Team  Type      From        To  Start X  Start Y    End X   End Y  \
# index
# 13     Home     1  424622.0  107672.0 -18.5288   26.112 -44.0059  15.504
# 18     Home     1  425341.0  151955.0  17.8239   -9.248  15.2057 -10.608
# 20     Home     1  151955.0  110619.0  16.0113   -6.732  18.5288  -1.632
# 22     Home     1  110619.0  249203.0  18.5288   -1.632  19.4351  22.304
# 23     Home     1  249203.0  110619.0  19.6365   24.684  22.2547  21.488
#
#        Start Frame  Start Time [s]  Period SIDE_OF_PITCH Subtype  frameIdx  \
# index
# 13           717.0           28.68       1         Right    Pass       717
# 18          1528.0           61.12       1          Left    Pass      1528
# 20          1568.0           62.72       1          Left    Pass      1568
# 22          1627.0           65.08       1          Left    Pass      1627
# 23          1711.0           68.44       1         Right    Pass      1711
#
#        ball_x  ball_y  ball_z
# index
# 13     -25.18   19.93    0.14
# 18      14.01  -14.12    1.39
# 20      12.21  -11.58    0.88
# 22      17.25    0.55    0.06
# 23      13.07   22.78    0.08

# %%
for i,row in home_passes.iloc[:5].iterrows():

    pass_start_pos = np.array([row['Start X'],row['Start Y']])
    pass_target_pos = np.array([row['End X'],row['End Y']])
    pass_frame = row['Start Frame']

    attacking_players = mpc.initialise_players(tracking_home.loc[pass_frame],'home',params, GK_numbers[0])
    defending_players = mpc.initialise_players(tracking_away.loc[pass_frame],'away',params, GK_numbers[1])
    Patt,Pdef = mpc.calculate_pitch_control_at_target(pass_target_pos, attacking_players, defending_players, pass_start_pos, params)
    pass_success_probability.append( (i,Patt) )
    mviz.plot_frame(tracking_home.loc[pass_frame], tracking_away.loc[pass_frame], include_player_velocities=True, annotate=True,field_dimen=(100.6,68.9))

# %%
home_passes.iloc[-5::]
# Out:
#        Team  Type      From        To  Start X  Start Y    End X   End Y  \
# index
# 1707   Home     1  219527.0  151940.0  -5.5385  -15.504  -4.5315   6.188
# 1708   Home     1  151940.0   82526.0 -12.7889    7.344 -28.8002 -28.968
# 1709   Home     1   82526.0  219527.0 -27.1890  -27.540 -22.0533 -19.992
# 1710   Home     1  219527.0  224546.0 -22.0533  -19.992 -22.2547  -8.976
# 1711   Home     1  224546.0       NaN -23.1610   -5.712 -10.5735   6.800
#
#        Start Frame  Start Time [s]  Period SIDE_OF_PITCH Subtype  frameIdx  \
# index
# 1707      138522.0         5540.88       2          Left    Pass    138522
# 1708      138659.0         5546.36       2         Right    Pass    138659
# 1709      138770.0         5550.80       2          Left    Pass    138770
# 1710      138826.0         5553.04       2          Left    Pass    138826
# 1711      138887.0         5555.48       2          Left    Pass    138887
#
#        ball_x  ball_y  ball_z
# index
# 1707    -4.58  -10.24    0.10
# 1708   -11.85   11.16    0.73
# 1709   -25.38  -22.83    0.09
# 1710   -16.85  -12.07    0.06
# 1711   -12.41    5.16    0.06

# %%
# evaluated pitch control surface for third pass
PPCF,xgrid,ygrid = mpc.generate_pitch_control_for_event(1707, home_passes, tracking_home, tracking_away, params, GK_numbers, n_grid_cells_x = 50,offsides=True,field_dimen=(100.6,68.9))

# %%
mviz.plot_pitchcontrol_for_event(1707, home_passes,  tracking_home, tracking_away, PPCF, annotate=True,field_dimen=(100.6,68.9))
# Out:
# (<Figure size 864x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# # Ball position seems messed up

# %% [markdown]
# ## Bring in Definitions for easier debugging

# %% [markdown]
# ## LINE 298 in __ is the culprit for generating pitch control atm
# **first get arrival time of 'nearest' attacking player (nearest also dependent on current velocity)**
#     tau_min_att = np.nanmin( [p.simple_time_to_intercept(target_position) for p in attacking_players] )
#     tau_min_def = np.nanmin( [p.simple_time_to_intercept(target_position ) for p in defending_players] )
#
#     print out target position, attacking players, defending players, ball position
#     print(target_position,attacking_players, defending_players, ball_start_pos)
#     [-51.94   -32.9375] [] [] [-19.504   1.632]

# %% [markdown]
# **I think the issue is the "attacking_players,defending_players" calculation - they are empty**

# %% [raw]
# in `generate_pitch_control_for event`:
# if pass_team=='Home':
#         attacking_players = initialise_players(tracking_home.loc[pass_frame],'Home',params,GK_numbers[0])
#         defending_players = initialise_players(tracking_away.loc[pass_frame],'Away',params,GK_numbers[1])
#     elif pass_team=='Away':
#         defending_players = initialise_players(tracking_home.loc[pass_frame],'Home',params,GK_numbers[0])
#         attacking_players = initialise_players(tracking_away.loc[pass_frame],'Away',params,GK_numbers[1])
#     else:

# %% [markdown]
# **LOOKING INTO initialise_players**
#
# This was the issue -

# %%
events.columns
# Out:
# Index(['Team', 'Type', 'From', 'To', 'Start X', 'Start Y', 'End X', 'End Y',
#        'Start Frame', 'Start Time [s]', 'Period', 'SIDE_OF_PITCH', 'Subtype',
#        'frameIdx', 'ball_x', 'ball_y', 'ball_z'],
#       dtype='object')

# %%
events.tail(7)
# Out:
#        Team  Type      From        To  Start X  Start Y    End X   End Y  \
# index
# 1705   Home     1  220150.0  223234.0 -22.2547  -29.172 -13.4938 -20.264
# 1706   Home     1  223234.0  219527.0 -13.4938  -20.264  -5.5385 -15.504
# 1707   Home     1  219527.0  151940.0  -5.5385  -15.504  -4.5315   6.188
# 1708   Home     1  151940.0   82526.0 -12.7889    7.344 -28.8002 -28.968
# 1709   Home     1   82526.0  219527.0 -27.1890  -27.540 -22.0533 -19.992
# 1710   Home     1  219527.0  224546.0 -22.0533  -19.992 -22.2547  -8.976
# 1711   Home     1  224546.0       NaN -23.1610   -5.712 -10.5735   6.800
#
#        Start Frame  Start Time [s]  Period SIDE_OF_PITCH Subtype  frameIdx  \
# index
# 1705      138424.0         5536.96       2          Left    Pass    138424
# 1706      138480.0         5539.20       2          Left    Pass    138480
# 1707      138522.0         5540.88       2          Left    Pass    138522
# 1708      138659.0         5546.36       2         Right    Pass    138659
# 1709      138770.0         5550.80       2          Left    Pass    138770
# 1710      138826.0         5553.04       2          Left    Pass    138826
# 1711      138887.0         5555.48       2          Left    Pass    138887
#
#        ball_x  ball_y  ball_z
# index
# 1705   -18.30  -27.01    0.06
# 1706   -10.94  -16.47    0.08
# 1707    -4.58  -10.24    0.10
# 1708   -11.85   11.16    0.73
# 1709   -25.38  -22.83    0.09
# 1710   -16.85  -12.07    0.06
# 1711   -12.41    5.16    0.06

# %%
# evaluated pitch control surface for third pass
PPCF,xgrid,ygrid = mpc.generate_pitch_control_for_event(13, events, tracking_home, tracking_away, params, GK_numbers, n_grid_cells_x = 50,offsides=True,field_dimen=(100.6,68.9))

# %%
mviz.plot_pitchcontrol_for_event(13, events,  tracking_home, tracking_away, PPCF, annotate=True,field_dimen=(100.6,68.9))
# Out:
# (<Figure size 864x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# ## Need to recalculate goalkeepers with event late in the game because the goalie was subbed out

# %%
# find goalkeepers for offside calculation
GK_numbers = [mio.find_goalkeeper(tracking_home,int(events.loc[1312]['Start Frame'])),
              mio.find_goalkeeper(tracking_away,int(events.loc[1312]['Start Frame']))]

# %%
events[events['Subtype']=='Goal']
# Out:
#        Team  Type      From  To  Start X  Start Y  End X  End Y  Start Frame  \
# index
# 1271   Away    16  124567.0 NaN  44.6101   -6.596    NaN    NaN     102161.0
# 1314   Away    16  153706.0 NaN  24.4701   -0.476    NaN    NaN     108011.0
#
#        Start Time [s]  Period SIDE_OF_PITCH Subtype  frameIdx  ball_x  ball_y  \
# index
# 1271          4086.44       2         Right    Goal    102161   43.65   -6.11
# 1314          4320.44       2         Right    Goal    108011   40.88   -1.57
#
#        ball_z
# index
# 1271     0.62
# 1314     2.67

# %%
events.loc[1268:1271]
# Out:
#        Team  Type      From        To  Start X  Start Y    End X   End Y  \
# index
# 1268   Away     1  153706.0  203718.0  23.4631   29.580  37.8632  27.948
# 1269   Away     1  203718.0   57252.0  37.7625   27.132  47.8325  14.960
# 1270   Away     1   57252.0  124567.0  47.8325   14.756  43.2003  -9.452
# 1271   Away    16  124567.0       NaN  44.6101   -6.596      NaN     NaN
#
#        Start Frame  Start Time [s]  Period SIDE_OF_PITCH Subtype  frameIdx  \
# index
# 1268      101957.0         4078.28       2          Left    Pass    101957
# 1269      102019.0         4080.76       2          Left    Pass    102019
# 1270      102095.0         4083.80       2          Left    Pass    102095
# 1271      102161.0         4086.44       2         Right    Goal    102161
#
#        ball_x  ball_y  ball_z
# index
# 1268    19.20   28.72    0.13
# 1269    35.82   29.43    0.14
# 1270    49.41   15.34    0.74
# 1271    43.65   -6.11    0.62

# %%
# plot the 3 events leading up to the first goal
mviz.plot_events(events.loc[1268:1270], color='k', indicators = ['Marker','Arrow'], annotate=True )
# Out:
# (<Figure size 864x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# ### Play with a cute little loop to calculate pitch control for the pass events leading up to the goal

# %%
def isNaN(num):
    '''cute lil guy that determines if an element is nan or not'''
    return num != num

# %%
# %%time
for i,row in events.loc[1268:1270].iterrows():
    if isNaN(row['End X']):
        print('----')
    else:
        # evaluated pitch control surface for each event
        event_frame=row['Start Frame']
        PPCF,xgrid,ygrid = mpc.generate_pitch_control_for_event(i, events, tracking_home, tracking_away, params, GK_numbers, n_grid_cells_x = 50,offsides=True,field_dimen=(100.6,68.9))
        fig, ax=mviz.plot_pitchcontrol_for_event(i, events,  tracking_home, tracking_away, PPCF, annotate=True,field_dimen=(100.6,68.9))
        ax.set_title("Team {}, From: {} To: {}, Event ID: {}".format(row['Team'],row['From'], row['To'],i))
        ax.set_xlabel("Ball loc_tracking: {},{}, Ball loc_events: {},{}".format(tracking_home['ball_x'].loc[event_frame],
                                                                                tracking_home['ball_y'].loc[event_frame],
                                                                                round(row['Start X'],2), round(row['Start Y'],2)),fontsize=12)
# Out:
# CPU times: user 9.23 s, sys: 83.8 ms, total: 9.32 s
# Wall time: 9.66 s

# %%
# plot the 3 events leading up to the first goal
mviz.plot_events( events.loc[1268:1270], color='k', indicators = ['Marker','Arrow'], annotate=True )
# Out:
# (<Figure size 864x576 with 1 Axes>, <AxesSubplot:>)

# %%
# evaluated pitch control surface for third pass
PPCF,xgrid,ygrid = mpc.generate_pitch_control_for_event(1270, events, tracking_home, tracking_away, params, GK_numbers, n_grid_cells_x = 50,offsides=True,field_dimen=(100.6,68.9))

# %%
mviz.plot_pitchcontrol_for_event(1270, events,  tracking_home, tracking_away, PPCF, annotate=True,field_dimen=(100.6,68.9))
# Out:
# (<Figure size 864x576 with 1 Axes>, <AxesSubplot:>)

# %%
events.loc[1268:1270]
# Out:
#        Team  Type      From        To  Start X  Start Y    End X   End Y  \
# index
# 1268   Away     1  153706.0  203718.0  23.4631   29.580  37.8632  27.948
# 1269   Away     1  203718.0   57252.0  37.7625   27.132  47.8325  14.960
# 1270   Away     1   57252.0  124567.0  47.8325   14.756  43.2003  -9.452
#
#        Start Frame  Start Time [s]  Period SIDE_OF_PITCH Subtype  frameIdx  \
# index
# 1268      101957.0         4078.28       2          Left    Pass    101957
# 1269      102019.0         4080.76       2          Left    Pass    102019
# 1270      102095.0         4083.80       2          Left    Pass    102095
#
#        ball_x  ball_y  ball_z
# index
# 1268    19.20   28.72    0.13
# 1269    35.82   29.43    0.14
# 1270    49.41   15.34    0.74

# %%
away_passes.shape
# Out:
# (640, 17)

# %%
away_passes.iloc[395:400]
# Out:
#        Team  Type      From        To  Start X  Start Y    End X   End Y  \
# index
# 972    Away     1  110618.0  203718.0 -13.2924   10.132 -18.2267 -10.404
# 973    Away     1  479760.0       NaN  23.6645  -11.084  36.7555  14.960
# 974    Away     1  203718.0  209818.0  36.7555   14.960  47.3290  -5.984
# 979    Away     1  421350.0       NaN  39.2730  -26.996  44.7108  -3.876
# 983    Away     1  213100.0  424622.0  49.5444  -33.660  44.4087  10.948
#
#        Start Frame  Start Time [s]  Period SIDE_OF_PITCH Subtype  frameIdx  \
# index
# 972        71595.0         2863.80       2          Left    Pass     71595
# 973        72116.0         2884.64       2         Right    Pass     72116
# 974        71692.0         2867.68       2          Left    Pass     71692
# 979        72581.0         2903.24       2         Right    Pass     72581
# 983        73764.0         2950.56       2         Right    Pass     73764
#
#        ball_x  ball_y  ball_z
# index
# 972    -13.96    5.93    0.14
# 973     -7.91  -19.98    0.06
# 974    -20.30    5.74    0.11
# 979       NaN     NaN     NaN
# 983     45.57  -19.01    5.21

# %%
tracking_home.shape
# Out:
# (139062, 107)

# %%
plt.figure(figsize=(15,5))
plt.plot(tracking_home.isnull().sum(axis=1))

# %%
# missing data
total = tracking_home.isnull().sum(axis=1).sort_values(ascending=False)
#percent = (events.isnull().sum()/events.isnull().count()).sort_values(ascending=False)

# %%
total.iloc[45375:45390]
# Out:
# frameIdx
# 2686      105
# 2687      105
# 2688      105
# 2689      105
# 2690      105
# 69466      69
# 47943      69
# 60421      69
# 69345      69
# 60422      69
# 69344      69
# 69343      69
# 127809     69
# 92784      69
# 116532     69
# dtype: int64

# %% [markdown]
# ## So we've got roughly 45 k of empty frames

# %%
#Calculate % missing data
tracking_home.isna().sum(axis=1)/len(tracking_home.columns)
# Out:
# frameIdx
# 0         0.644860
# 1         0.644860
# 2         0.644860
# 3         0.644860
# 4         0.336449
#             ...
# 139057    0.336449
# 139058    0.336449
# 139059    0.336449
# 139060    0.336449
# 139061    0.336449
# Length: 139062, dtype: float64

# %% [markdown]
# ## Quantifying Pass probability for AWAY TEAM

# %%
away_pass_success_probability=[]

# %%
for i,row in away_passes.iterrows():
    ### This if statement checks if more than 90/107 rows are nan, if so, it skips
    if list(tracking_home[tracking_home.index==row['Start Frame']].isnull().sum(axis=1))[0]>90:
        pass
    else:
        pass_start_pos = np.array([row['Start X'],row['Start Y']])
        pass_target_pos = np.array([row['End X'],row['End Y']])
        pass_frame = row['Start Frame']
        # find goalkeepers for offside calculation and so player initialization works properly 
        #      - calculating them for each frame in case of substitutions
        GK_numbers = [mio.find_goalkeeper(tracking_home,int(row['Start Frame'])),
                      mio.find_goalkeeper(tracking_away,int(row['Start Frame']))]
        attacking_players = mpc.initialise_players(tracking_away.loc[pass_frame],'away',params, GK_numbers[1])
        defending_players = mpc.initialise_players(tracking_home.loc[pass_frame],'home',params, GK_numbers[0])

        Patt,Pdef = mpc.calculate_pitch_control_at_target(pass_target_pos, attacking_players, defending_players, pass_start_pos, params)

        away_pass_success_probability.append( (i,Patt) )

# %%
len(away_pass_success_probability)
# Out:
# 639

# %%
fig,ax = plt.subplots()
ax.hist( [p[1] for p in away_pass_success_probability], np.arange(0,1.1,0.1))    
ax.set_xlabel('Pass success probability')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## How this compares to pass probability - "Pass Difficulty"
# ****Plot regression

# %%
# sort the passes by pitch control probability
away_pass_success_probability = sorted(away_pass_success_probability, key = lambda x: x[1] )

# identify the events corresponding to the most risky passes (pitch control < 0.5)
risky_away_passes = events.loc[ [p[0] for p in away_pass_success_probability if (p[1]>0.2) and (p[1]<0.4) ] ]

# %% [raw]
# del pass_success_probability[0:11]

# %%
away_pass_success_probability[:20]
# Out:
# [(974, 0.0),
#  (1157, 0.0),
#  (1643, 0.0),
#  (1644, 0.0),
#  (1645, 0.0),
#  (970, 1.3710035270120317e-06),
#  (176, 1.0228955031460134e-05),
#  (275, 1.3134712208654452e-05),
#  (973, 2.672367131000327e-05),
#  (455, 2.6810893949793028e-05),
#  (1002, 3.055977025074524e-05),
#  (103, 4.402645360305874e-05),
#  (219, 0.00016513008235865875),
#  (866, 0.0007484950245215743),
#  (939, 0.0011999635458490867),
#  (638, 0.003950288255992228),
#  (1026, 0.004994772628692943),
#  (1666, 0.006234200228920525),
#  (844, 0.008108048256174023),
#  (736, 0.009896926918612162)]

# %%
# Print events that followed those risky passes
print("Event following a risky (completed) pass")
for p in away_pass_success_probability[:20]:
    if p[0]+1 in events.index:
        outcome = events.loc[ p[0]+1 ]['Subtype']
        print( p[1], outcome )
        #print('here')
    else:
        outcome = events.loc[ p[0]+2 ]['Subtype']
        print( p[1], outcome )
        #print('there')
# Out:
# Event following a risky (completed) pass
# 0.0 Clearance
# 0.0 Out
# 0.0 Pass
# 0.0 Pass
# 0.0 Foul
# 1.3710035270120317e-06 Ball_recovery
# 1.0228955031460134e-05 Keeper_pick-up
# 1.3134712208654452e-05 Keeper_pick-up
# 2.672367131000327e-05 Pass
# 2.6810893949793028e-05 Interception
# 3.055977025074524e-05 Formation_change
# 4.402645360305874e-05 Keeper_pick-up
# 0.00016513008235865875 Ball_recovery
# 0.0007484950245215743 Pass
# 0.0011999635458490867 Pass
# 0.003950288255992228 Ball_recovery
# 0.004994772628692943 Ball_recovery
# 0.006234200228920525 Ball_recovery
# 0.008108048256174023 Out
# 0.009896926918612162 Pass

# %% [markdown]
# ## Pitch control at these risky passes would be interesting

# %%
# plot the events
mviz.plot_events( risky_away_passes, color='k', indicators = ['Marker','Arrow'], annotate=True,field_dimen=(100.6,68.9) )
# Out:
# (<Figure size 864x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# ## Quantifying Pass Probability for HOME TEAM

# %%
home_pass_success_probability=[]

# %%
for i,row in home_passes.iterrows():
    ### This if statement checks if more than 90/107 rows are nan, if so, it skips
    if list(tracking_home[tracking_home.index==row['Start Frame']].isnull().sum(axis=1))[0]>90:
        pass
    else:
        pass_start_pos = np.array([row['Start X'],row['Start Y']])
        pass_target_pos = np.array([row['End X'],row['End Y']])
        pass_frame = row['Start Frame']
        # find goalkeepers for offside calculation and so player initialization works properly 
        #      - calculating them for each frame in case of substitutions
        GK_numbers = [mio.find_goalkeeper(tracking_home,int(row['Start Frame'])),
                      mio.find_goalkeeper(tracking_away,int(row['Start Frame']))]
        attacking_players = mpc.initialise_players(tracking_home.loc[pass_frame],'home',params, GK_numbers[0])
        defending_players = mpc.initialise_players(tracking_away.loc[pass_frame],'away',params, GK_numbers[1])

        Patt,Pdef = mpc.calculate_pitch_control_at_target(pass_target_pos, attacking_players, defending_players, pass_start_pos, params)

        home_pass_success_probability.append( (i,Patt) )

# %%
len(home_pass_success_probability)
# Out:
# 414

# %%
fig,ax = plt.subplots()
ax.hist( [p[1] for p in home_pass_success_probability], np.arange(0,1.1,0.1))    
ax.set_xlabel('Pass success probability')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## How this compares to pass probability - "Pass Difficulty"
# ****Plot regression

# %%
# sort the passes by pitch control probability
home_pass_success_probability = sorted(home_pass_success_probability, key = lambda x: x[1] )

# identify the events corresponding to the most risky passes (pitch control < 0.5)
risky_home_passes = events.loc[ [p[0] for p in home_pass_success_probability if (p[1]>0.2) and (p[1]<0.4) ] ]

# %% [raw]
# del pass_success_probability[0:11]

# %%
home_pass_success_probability[:20]
# Out:
# [(1105, 0.0),
#  (1106, 0.0),
#  (1163, 1.1780140360196399e-05),
#  (1599, 1.2955945372487874e-05),
#  (1102, 8.768720882691785e-05),
#  (1031, 0.000682889134038467),
#  (1307, 0.0006857302215252967),
#  (1030, 0.001999826056689097),
#  (461, 0.0023615685672379646),
#  (859, 0.0028903510641568953),
#  (1600, 0.003224457403699003),
#  (64, 0.004496161386275988),
#  (1112, 0.006648463686907349),
#  (1009, 0.0078914221581281),
#  (1248, 0.010651372840144398),
#  (1036, 0.011430231143780466),
#  (1034, 0.013297655523952049),
#  (1035, 0.014074488615145082),
#  (379, 0.014705277122388144),
#  (656, 0.016754379330815944)]

# %%
# Print events that followed those risky passes
print("Event following a risky (completed) pass")
for p in home_pass_success_probability[:20]:
    if p[0]+1 in events.index:
        outcome = events.loc[ p[0]+1 ]['Subtype']
        print( p[1], outcome )
        #print('here')
    else:
        outcome = events.loc[ p[0]+2 ]['Subtype']
        print( p[1], outcome )
        #print('there')
# Out:
# Event following a risky (completed) pass
# 0.0 Pass
# 0.0 Out
# 1.1780140360196399e-05 Pass
# 1.2955945372487874e-05 Pass
# 8.768720882691785e-05 Aerial
# 0.000682889134038467 Pass
# 0.0006857302215252967 Ball_recovery
# 0.001999826056689097 Pass
# 0.0023615685672379646 Out
# 0.0028903510641568953 Keeper_pick-up
# 0.003224457403699003 Foul
# 0.004496161386275988 Out
# 0.006648463686907349 Interception
# 0.0078914221581281 Ball_recovery
# 0.010651372840144398 Ball_recovery
# 0.011430231143780466 Ball_recovery
# 0.013297655523952049 Pass
# 0.014074488615145082 Pass
# 0.014705277122388144 Out
# 0.016754379330815944 Pass

# %% [markdown]
# ## Pitch control at these risky passes would be interesting

# %%
# plot the events
mviz.plot_events( risky_home_passes, color='k', indicators = ['Marker','Arrow'], annotate=True,field_dimen=(100.6,68.9) )
# Out:
# (<Figure size 864x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# # Plot Pitch surface for 5-10 riskiest passes for HOME TEAM

# %%
# %%time
for i,row in risky_home_passes.iloc[:6].iterrows():
    if isNaN(row['End X']):
        print('----')
    else:
        # evaluated pitch control surface for each event
        PPCF,xgrid,ygrid = mpc.generate_pitch_control_for_event(i, events, tracking_home, tracking_away, params, GK_numbers, n_grid_cells_x = 50,offsides=True,field_dimen=(100.6,68.9))
        fig, ax=mviz.plot_pitchcontrol_for_event(i, events,  tracking_home, tracking_away, PPCF, annotate=True,field_dimen=(100.6,68.9))
        ax.set_title("Team {}, From: {} To: {}, Event ID: {}".format(row['Team'],row['From'], row['To'],i))
        ax.set_xlabel("Ball loc_tracking: {},{}, Ball loc_events: {},{}".format(tracking_home['ball_x'].loc[event_frame],
                                                                                tracking_home['ball_y'].loc[event_frame],
                                                                                round(row['Start X'],2), round(row['Start Y'],2)),fontsize=12)
# Out:
# CPU times: user 29.6 s, sys: 321 ms, total: 29.9 s
# Wall time: 32 s

# %% [markdown]
# ## ADJUST PITCH CONTROL model so it takes the ball start position from the tracking data NOT event data
